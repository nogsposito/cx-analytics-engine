# %% [markdown]
# ## Notebook #2: Limpando e preparando os dados

# %% [markdown]
# #### Este notebook tem como objetivo medir e definir or dados usados para a solução, fazendo as limpezas necessárias e preparando uma base para a análise.

# %% [markdown]
# Para primeiro plano, apenas as entregas consideradas como concluídas (delivered) serão consideradas. Isso será feito para evitar que pedidos cancelados influenciem a análise, já que as métricas não deveriam se aplicar da mesma forma.

# %% [markdown]
# ### Limpeza

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
orders = pd.read_csv('../data/raw/olist_orders_dataset.csv')
reviews = pd.read_csv('../data/raw/olist_order_reviews_dataset.csv')
customers = pd.read_csv('../data/raw/olist_customers_dataset.csv')

# %% [markdown]
# -> Pedidos não marcados como entregues excluídos

# %%
orders_clean = orders[orders['order_status'] == 'delivered'].copy()

# %%
#orders_clean = pd.read_csv(orders_clean, parse_dates=[
#    'order_purchase_timestamp', 
#    'order_approved_at', 
#    'order_delivered_carrier_date', 
#    'order_delivered_customer_date', 
#    'order_estimated_delivery_date'
#])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 orders_clean = pd.read_csv(orders_clean, parse_dates=[
#       2     'order_purchase_timestamp',
#       3     'order_approved_at',
#       4     'order_delivered_carrier_date',
#       5     'order_delivered_customer_date',
#       6     'order_estimated_delivery_date'
#       7 ])
#
# ...

# %%
#reviews_clean = pd.read_csv(reviews, parse_dates=[
#    'review_creation_date', 
#    'review_answer_timestamp'
#])

# %%
#reviews_clean.info()

# %%
#orders_clean.info()
